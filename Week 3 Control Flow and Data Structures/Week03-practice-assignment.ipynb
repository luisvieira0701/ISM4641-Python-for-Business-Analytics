# %% [markdown]
# # Week 3 Practice Assignment: Control Flow and Data Structures
#
# **ISM4641 - Python for Business Analytics**
# **Status:** Optional (Bonus Credit)
# **Bonus:** Completing all practice assignments contributes to a 3% bonus on your final grade
#
# ---
#
# ## About Practice Assignments
#
# Practice assignments help you build fluency with Python syntax and techniques through focused exercises. They complement the main **Integrative Assignments**, which apply these skills to realistic business scenarios.
#
# **Completing practice assignments is optional but recommended if you want to:**
# - Reinforce the week's concepts through hands-on practice
# - Build confidence before tackling the integrative assignment
# - Earn bonus credit toward your final grade
#
# ## Instructions
#
# 1. Complete all exercises in this notebook
# 2. Run each code cell to verify your answers work correctly
# 3. Submit this notebook (.ipynb file) to Canvas
# 4. No video walkthrough required for practice assignments

# %% [markdown]
# ---
# ## Student Information
#
# **Name:** [Enter your name here]
# **USF ID:** [Enter your ID here]
# **Date:** [Enter date here]

# %% [markdown]
# ---
# ## Exercise 1: Customer Tier Classification (2 points)
#
# A retail company classifies customers into tiers based on their annual spending:
#
# | Annual Spending | Tier | Discount |
# |-----------------|------|----------|
# | $10,000+ | Diamond | 25% |
# | $5,000 - $9,999 | Platinum | 20% |
# | $2,000 - $4,999 | Gold | 15% |
# | $500 - $1,999 | Silver | 10% |
# | Below $500 | Bronze | 5% |
#
# Write code that:
# 1. Takes an `annual_spending` value
# 2. Determines the customer's tier and discount using `if/elif/else`
# 3. Prints the tier name and discount percentage
#
# **Test your code with:** $3,500, $12,000, and $250

# %%
# Exercise 1: Your code here

# Test with different spending amounts
annual_spending = 3500  # Change this to test different values

# Determine tier and discount using if/elif/else


# Print the results

# %% [markdown]
# ---
# ## Exercise 2: Sales Performance Analysis (2 points)
#
# You have a list of daily sales figures for a week:
#
# ```python
# daily_sales = [1250.50, 980.25, 1567.00, 890.75, 2100.00, 1450.25, 1780.50]
# ```
#
# Write code using a `for` loop to:
# 1. Calculate the total weekly sales
# 2. Find the highest and lowest daily sales
# 3. Calculate the average daily sales
# 4. Count how many days had sales above $1,500
#
# Print all results with appropriate labels.

# %%
# Exercise 2: Your code here

daily_sales = [1250.50, 980.25, 1567.00, 890.75, 2100.00, 1450.25, 1780.50]

# Calculate total, highest, lowest, average, and count above $1,500


# Print results

# %% [markdown]
# ---
# ## Exercise 3: Inventory Management (2 points)
#
# You have a dictionary representing product inventory:
#
# ```python
# inventory = {
#     "Laptop": {"quantity": 15, "price": 999.99, "reorder_point": 10},
#     "Mouse": {"quantity": 8, "price": 29.99, "reorder_point": 20},
#     "Keyboard": {"quantity": 25, "price": 79.99, "reorder_point": 15},
#     "Monitor": {"quantity": 5, "price": 299.99, "reorder_point": 8},
#     "Webcam": {"quantity": 30, "price": 89.99, "reorder_point": 12}
# }
# ```
#
# Write code to:
# 1. Calculate the total inventory value (quantity * price for each product)
# 2. Create a list of products that need to be reordered (quantity < reorder_point)
# 3. Find the most expensive product
# 4. Print a formatted inventory report

# %%
# Exercise 3: Your code here

inventory = {
    "Laptop": {"quantity": 15, "price": 999.99, "reorder_point": 10},
    "Mouse": {"quantity": 8, "price": 29.99, "reorder_point": 20},
    "Keyboard": {"quantity": 25, "price": 79.99, "reorder_point": 15},
    "Monitor": {"quantity": 5, "price": 299.99, "reorder_point": 8},
    "Webcam": {"quantity": 30, "price": 89.99, "reorder_point": 12}
}

# Calculate total inventory value


# Find products that need reordering


# Find most expensive product


# Print inventory report

# %% [markdown]
# ---
# ## Exercise 4: Loan Qualification Checker (2 points)
#
# A bank has the following loan qualification criteria:
#
# **For a loan to be APPROVED, ALL conditions must be met:**
# - Credit score >= 650
# - Annual income >= $40,000
# - Debt-to-income ratio < 40%
# - Employment years >= 2
#
# Write code that:
# 1. Takes applicant information as variables
# 2. Uses logical operators (`and`, `or`, `not`) to check eligibility
# 3. If NOT approved, identifies which condition(s) failed
# 4. Prints the decision with explanation
#
# **Test with these applicants:**
# - Applicant A: credit_score=720, income=55000, debt=18000, years_employed=3
# - Applicant B: credit_score=580, income=62000, debt=15000, years_employed=5

# %%
# Exercise 4: Your code here

# Applicant information
credit_score = 720
annual_income = 55000
total_debt = 18000
years_employed = 3

# Calculate debt-to-income ratio


# Check each condition and overall eligibility


# Print decision with explanation

# %% [markdown]
# ---
# ## Exercise 5: Sales Commission Calculator (2 points)
#
# A company pays sales representatives based on their monthly sales:
#
# | Monthly Sales | Commission Rate |
# |---------------|----------------|
# | First $5,000 | 5% |
# | $5,001 - $10,000 | 8% |
# | $10,001 - $20,000 | 10% |
# | Above $20,000 | 12% |
#
# **Important:** Commission is calculated in tiers. For example, if sales are $15,000:
# - 5% on first $5,000 = $250
# - 8% on next $5,000 ($5,001-$10,000) = $400
# - 10% on remaining $5,000 ($10,001-$15,000) = $500
# - Total commission = $1,150
#
# Write code that:
# 1. Takes a `monthly_sales` amount
# 2. Calculates the tiered commission using a `while` loop or conditionals
# 3. Prints a breakdown of commission at each tier
# 4. Prints the total commission earned
#
# **Test with:** $8,000, $15,000, and $25,000

# %%
# Exercise 5: Your code here

monthly_sales = 15000  # Change to test different values

# Define tier boundaries and rates


# Calculate tiered commission


# Print breakdown and total

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] All code cells run without errors
# - [ ] All exercises are completed
# - [ ] Student information is filled in
# - [ ] Code includes appropriate comments
#
# ---
# *ISM4641 Python for Business Analytics - Week 3 Practice Assignment*
