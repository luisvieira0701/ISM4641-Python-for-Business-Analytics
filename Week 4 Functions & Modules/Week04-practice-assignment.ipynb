# %% [markdown]
# # Week 4 Practice Assignment: Functions and Modules
#
# **ISM4641 - Python for Business Analytics**
# **Status:** Optional (Bonus Credit)
# **Bonus:** Completing all practice assignments contributes to a 3% bonus on your final grade
#
# ---
#
# ## About Practice Assignments
#
# Practice assignments help you build fluency with Python syntax and techniques through focused exercises. They complement the main **Integrative Assignments**, which apply these skills to realistic business scenarios.
#
# **Completing practice assignments is optional but recommended if you want to:**
# - Reinforce the week's concepts through hands-on practice
# - Build confidence before tackling the integrative assignment
# - Earn bonus credit toward your final grade
#
# ## Instructions
#
# 1. Complete all exercises in this notebook
# 2. Run each code cell to verify your answers work correctly
# 3. Submit this notebook (.ipynb file) to Canvas
# 4. No video walkthrough required for practice assignments

# %% [markdown]
# ---
# ## Student Information
#
# **Name:** [Enter your name here]
# **USF ID:** [Enter your ID here]
# **Date:** [Enter date here]

# %% [markdown]
# ---
# ## Exercise 1: Tip Calculator Function (2 points)
#
# Create a function called `calculate_bill` that:
#
# **Parameters:**
# - `subtotal`: The bill amount before tip (required)
# - `tip_percent`: Tip percentage (default: 18)
# - `split`: Number of people splitting the bill (default: 1)
#
# **Returns:** A dictionary with:
# - `subtotal`: Original bill amount
# - `tip_amount`: Calculated tip
# - `total`: Subtotal + tip
# - `per_person`: Total divided by number of people
#
# **Test your function with:**
# 1. Subtotal of $85.50 with default tip, no split
# 2. Subtotal of $120.00 with 20% tip, split 4 ways

# %%
# Exercise 1: Your code here

def calculate_bill(subtotal, tip_percent=18, split=1):
    """Calculate bill with tip and optional split."""
    # Your code here
    pass

# Test 1: Default tip, no split


# Test 2: 20% tip, split 4 ways

# %% [markdown]
# ---
# ## Exercise 2: Employee Payroll Calculator (2 points)
#
# Create a function called `calculate_payroll` that:
#
# **Parameters:**
# - `hours_worked`: Number of hours worked
# - `hourly_rate`: Pay rate per hour
# - `overtime_threshold`: Hours after which overtime applies (default: 40)
# - `overtime_multiplier`: Overtime rate multiplier (default: 1.5)
#
# **Returns:** A tuple of (regular_pay, overtime_pay, gross_pay)
#
# **Business Logic:**
# - Regular pay = hours up to threshold × hourly rate
# - Overtime pay = hours over threshold × hourly rate × overtime multiplier
#
# **Test with:**
# 1. 35 hours at $25/hour (no overtime)
# 2. 48 hours at $25/hour (with overtime)
# 3. 50 hours at $30/hour with 35-hour threshold and 2x overtime

# %%
# Exercise 2: Your code here

def calculate_payroll(hours_worked, hourly_rate, overtime_threshold=40, overtime_multiplier=1.5):
    """Calculate employee pay including overtime."""
    # Your code here
    pass

# Test cases

# %% [markdown]
# ---
# ## Exercise 3: Password Validator (2 points)
#
# Create a function called `validate_password` that checks if a password meets these criteria:
#
# **Requirements:**
# - At least 8 characters long
# - Contains at least one uppercase letter
# - Contains at least one lowercase letter
# - Contains at least one digit
# - Contains at least one special character (!@#$%^&*)
#
# **Returns:** A dictionary with:
# - `is_valid`: True if all requirements met, False otherwise
# - `errors`: List of failed requirements (empty if valid)
#
# **Hint:** Use string methods like `.isupper()`, `.islower()`, `.isdigit()`
#
# **Test with:**
# 1. "weak"
# 2. "StrongPass1!"
# 3. "NoSpecial123"

# %%
# Exercise 3: Your code here

def validate_password(password):
    """Validate password against security requirements."""
    # Your code here
    pass

# Test cases

# %% [markdown]
# ---
# ## Exercise 4: Sales Report Generator (2 points)
#
# Create a function called `generate_sales_report` that uses the `datetime` module:
#
# **Parameters:**
# - `sales_data`: List of dictionaries with keys: 'product', 'quantity', 'price'
# - `report_title`: Title for the report (default: "Sales Report")
#
# **The function should:**
# 1. Calculate total revenue for each product
# 2. Calculate overall total revenue
# 3. Find the best-selling product (by revenue)
# 4. Include the current date/time in the report header
#
# **Print a formatted report and return a dictionary with summary statistics.**
#
# **Test with the provided sales data:**

# %%
# Exercise 4: Your code here

from datetime import datetime

def generate_sales_report(sales_data, report_title="Sales Report"):
    """Generate a formatted sales report with summary statistics."""
    # Your code here
    pass

# Test data
sales = [
    {"product": "Laptop", "quantity": 5, "price": 999.99},
    {"product": "Mouse", "quantity": 25, "price": 29.99},
    {"product": "Keyboard", "quantity": 15, "price": 79.99},
    {"product": "Monitor", "quantity": 8, "price": 299.99},
    {"product": "Webcam", "quantity": 12, "price": 89.99}
]

# Generate report

# %% [markdown]
# ---
# ## Exercise 5: Random Quiz Generator (2 points)
#
# Create a function called `generate_quiz` that uses the `random` module:
#
# **Parameters:**
# - `question_bank`: List of dictionaries with keys: 'question', 'options', 'answer'
# - `num_questions`: Number of questions to include (default: 5)
# - `shuffle_options`: Whether to shuffle the answer options (default: True)
#
# **The function should:**
# 1. Randomly select questions from the bank (without replacement)
# 2. Optionally shuffle the options for each question
# 3. Return a list of selected questions
#
# **Also create a function `grade_quiz` that:**
# - Takes a quiz (list of questions) and user_answers (list of answers)
# - Returns score as percentage and list of incorrect questions
#
# **Test with the provided question bank:**

# %%
# Exercise 5: Your code here

import random

def generate_quiz(question_bank, num_questions=5, shuffle_options=True):
    """Generate a random quiz from a question bank."""
    # Your code here
    pass

def grade_quiz(quiz, user_answers):
    """Grade a quiz and return score with feedback."""
    # Your code here
    pass

# Question bank
question_bank = [
    {
        "question": "What keyword defines a function in Python?",
        "options": ["def", "function", "func", "define"],
        "answer": "def"
    },
    {
        "question": "What does the return statement do?",
        "options": ["Exits the program", "Prints a value", "Sends a value back to caller", "Creates a loop"],
        "answer": "Sends a value back to caller"
    },
    {
        "question": "Which module provides random number functions?",
        "options": ["math", "random", "numbers", "rand"],
        "answer": "random"
    },
    {
        "question": "What is a local variable?",
        "options": ["Variable defined inside a function", "Variable defined outside functions", "Variable that never changes", "Variable shared between files"],
        "answer": "Variable defined inside a function"
    },
    {
        "question": "How do you import only sqrt from the math module?",
        "options": ["import sqrt from math", "from math import sqrt", "import math.sqrt", "math import sqrt"],
        "answer": "from math import sqrt"
    },
    {
        "question": "What does math.ceil(4.2) return?",
        "options": ["4", "5", "4.2", "4.0"],
        "answer": "5"
    },
    {
        "question": "What is a docstring?",
        "options": ["A type of variable", "Documentation for a function", "A string that contains 'doc'", "A module name"],
        "answer": "Documentation for a function"
    }
]

# Generate and display quiz


# Simulate answering and grading

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] All code cells run without errors
# - [ ] All exercises are completed
# - [ ] Student information is filled in
# - [ ] Code includes appropriate comments
#
# ---
# *ISM4641 Python for Business Analytics - Week 4 Practice Assignment*
