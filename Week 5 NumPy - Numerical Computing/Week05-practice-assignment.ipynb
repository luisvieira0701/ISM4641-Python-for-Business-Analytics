# %% [markdown]
# # Week 5 Practice Assignment: NumPy Fundamentals
#
# **ISM4641 - Python for Business Analytics**
# **Status:** Optional (Bonus Credit)
# **Bonus:** Completing all practice assignments contributes to a 3% bonus on your final grade
#
# ---
#
# ## About Practice Assignments
#
# Practice assignments help you build fluency with Python syntax and techniques through focused exercises. They complement the main **Integrative Assignments**, which apply these skills to realistic business scenarios.
#
# **Completing practice assignments is optional but recommended if you want to:**
# - Reinforce the week's concepts through hands-on practice
# - Build confidence before tackling the integrative assignment
# - Earn bonus credit toward your final grade
#
# ## Instructions
#
# 1. Complete all exercises in this notebook
# 2. Run each code cell to verify your answers work correctly
# 3. Submit this notebook (.ipynb file) to Canvas
# 4. No video walkthrough required for practice assignments

# %% [markdown]
# ---
# ## Student Information
#
# **Name:** [Enter your name here]
# **USF ID:** [Enter your ID here]
# **Date:** [Enter date here]

# %%
# Import NumPy - run this cell first!
import numpy as np

# %% [markdown]
# ---
# ## Exercise 1: Sales Performance Dashboard (2 points)
#
# A retail company has recorded daily sales for 4 weeks (28 days). Using the provided data:
#
# 1. Calculate basic statistics: mean, median, std, min, max
# 2. Find the number of days with sales above $1,500
# 3. Calculate the total revenue for each week
# 4. Find which week had the highest average daily sales
# 5. Print a formatted summary report

# %%
# Exercise 1: Your code here

# Daily sales data (28 days, 4 weeks)
daily_sales = np.array([
    1250, 1380, 1520, 1150, 1680, 1920, 1340,  # Week 1
    1450, 1290, 1670, 1580, 1820, 2100, 1480,  # Week 2
    1320, 1410, 1560, 1290, 1750, 1890, 1520,  # Week 3
    1680, 1590, 1820, 1450, 1930, 2200, 1670   # Week 4
])

# Reshape to 4 weeks x 7 days for weekly analysis


# Calculate statistics


# Print formatted report

# %% [markdown]
# ---
# ## Exercise 2: Product Portfolio Analysis (2 points)
#
# Analyze a product portfolio using vectorized operations:
#
# 1. Calculate revenue for each product (price × quantity)
# 2. Calculate profit for each product ((price - cost) × quantity)
# 3. Calculate profit margin percentage for each product
# 4. Find the top 3 products by profit
# 5. Calculate total portfolio metrics (revenue, cost, profit, average margin)

# %%
# Exercise 2: Your code here

products = np.array(['Laptop', 'Mouse', 'Keyboard', 'Monitor', 'Webcam', 'Headset', 'USB Hub', 'Mousepad'])
prices = np.array([999.99, 29.99, 79.99, 299.99, 89.99, 149.99, 49.99, 19.99])
costs = np.array([650.00, 12.00, 35.00, 180.00, 45.00, 75.00, 22.00, 8.00])
quantities = np.array([50, 200, 150, 75, 100, 80, 120, 300])

# Calculate metrics


# Find top 3 products by profit


# Print analysis

# %% [markdown]
# ---
# ## Exercise 3: Regional Sales Comparison (2 points)
#
# Compare sales performance across 4 regions over 4 quarters:
#
# 1. Calculate total annual sales for each region
# 2. Calculate quarterly totals across all regions
# 3. Find the best and worst performing region
# 4. Calculate quarter-over-quarter growth rates for each region
# 5. Identify which region had the most consistent performance (lowest std deviation)

# %%
# Exercise 3: Your code here

# Sales data: rows = regions, columns = quarters (in thousands)
regional_sales = np.array([
    [120, 135, 142, 128],  # North
    [95, 105, 118, 110],   # South
    [145, 160, 175, 168],  # East
    [88, 95, 102, 98]      # West
])

regions = ['North', 'South', 'East', 'West']
quarters = ['Q1', 'Q2', 'Q3', 'Q4']

# Calculate metrics


# Print analysis

# %% [markdown]
# ---
# ## Exercise 4: Customer Segmentation (2 points)
#
# Segment customers based on their spending patterns:
#
# 1. Use boolean indexing to create segments:
#    - VIP: spending >= $5,000
#    - Regular: spending between $1,000 and $5,000
#    - Occasional: spending < $1,000
# 2. Calculate the count and total spending for each segment
# 3. Find the average spending per segment
# 4. Calculate what percentage of total revenue each segment contributes

# %%
# Exercise 4: Your code here

# Customer spending data (annual spending in dollars)
customer_spending = np.array([
    5200, 890, 3400, 7800, 450, 2100, 6500, 980,
    1500, 4200, 780, 5800, 2800, 650, 3900, 8200,
    1200, 4500, 560, 6100, 2400, 890, 5100, 3200,
    950, 7200, 1800, 420, 4800, 6800
])

# Create segments using boolean indexing


# Calculate segment metrics


# Print segmentation report

# %% [markdown]
# ---
# ## Exercise 5: Price Optimization Simulation (2 points)
#
# Simulate the effect of different pricing strategies:
#
# 1. Create an array of prices from $50 to $150 in $5 increments
# 2. Assume demand follows this formula: demand = 1000 - 5 × price
# 3. Calculate revenue at each price point (price × demand)
# 4. Find the optimal price that maximizes revenue
# 5. Create a summary showing price, demand, and revenue for the top 5 price points
#
# **Bonus:** Consider a cost of $30 per unit and find the price that maximizes profit instead of revenue.

# %%
# Exercise 5: Your code here

# Create price array


# Calculate demand at each price


# Calculate revenue


# Find optimal price


# Print analysis


# Bonus: Profit optimization (cost = $30)

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] All code cells run without errors
# - [ ] All exercises are completed
# - [ ] Student information is filled in
# - [ ] Code includes appropriate comments
#
# ---
# *ISM4641 Python for Business Analytics - Week 5 Practice Assignment*
