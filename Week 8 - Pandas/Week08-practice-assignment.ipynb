# %% [markdown]
# # Week 8 Practice Assignment: Pandas for Business Analytics
#
# **ISM4641 - Python for Business Analytics**
# **Status:** Optional (Bonus Credit)
# **Bonus:** Completing all practice assignments contributes to a 3% bonus on your final grade
#
# ---
#
# ## About Practice Assignments
#
# Practice assignments help you build fluency with Python syntax and techniques through focused exercises. They complement the main **Integrative Assignments**, which apply these skills to realistic business scenarios.
#
# **Completing practice assignments is optional but recommended if you want to:**
# - Reinforce the week's concepts through hands-on practice
# - Build confidence before tackling the integrative assignment
# - Earn bonus credit toward your final grade
#
# ## Instructions
#
# 1. Complete all exercises in this notebook
# 2. Run each code cell to verify your answers work correctly
# 3. Submit this notebook (.ipynb file) to Canvas
# 4. No video walkthrough required for practice assignments

# %% [markdown]
# ---
# ## Student Information
#
# **Name:** [Enter your name here]
# **USF ID:** [Enter your ID here]
# **Date:** [Enter date here]

# %%
# Import libraries - run this cell first!
import pandas as pd
import numpy as np

# Data repository URL
DATA_URL = "https://raw.githubusercontent.com/prof-tcsmith/4641s26-data/main"

# %% [markdown]
# ---
# ## Exercise 1: Employee Performance Analysis (2 points)
#
# A company wants to analyze employee performance data. Using the provided DataFrame:
#
# 1. Calculate the average salary for each department
# 2. Find all employees with a performance rating of 4 or higher
# 3. Add a new column 'Bonus' that is 10% of salary for ratings >= 4, otherwise 5%
# 4. Find the employee with the highest salary in each department
# 5. Print a summary report with your findings

# %%
# Exercise 1: Your code here

# Load employee data from course data repository
employees = pd.read_csv(f"{DATA_URL}/week08/employees.csv")

print("Employee Data:")
display(employees)

# 1. Average salary by department


# 2. High performers (rating >= 4)


# 3. Add Bonus column


# 4. Highest salary per department


# 5. Summary report

# %% [markdown]
# ---
# ## Exercise 2: Retail Sales Analysis (2 points)
#
# Analyze retail sales data across multiple stores:
#
# 1. Calculate total sales for each store
# 2. Find the best-selling product category overall
# 3. Calculate the average transaction value (Sales / Transactions) for each store
# 4. Identify stores where Electronics sales exceed $20,000
# 5. Create a summary showing total sales and transactions by store

# %%
# Exercise 2: Your code here

# Load retail sales data from course data repository
sales_data = pd.read_csv(f"{DATA_URL}/week08/retail_sales.csv")

print("Sales Data:")
display(sales_data)

# 1. Total sales by store


# 2. Best-selling category


# 3. Average transaction value by store


# 4. Stores with Electronics > $20,000


# 5. Summary by store

# %% [markdown]
# ---
# ## Exercise 3: Customer Order Analysis (2 points)
#
# Combine order and customer data to perform a comprehensive analysis:
#
# 1. Merge the orders and customers DataFrames
# 2. Calculate total order amount per customer
# 3. Find the customer who spent the most money
# 4. Calculate average order amount by city
# 5. Identify customers who have placed more than 2 orders

# %%
# Exercise 3: Your code here

# Load orders and customers data from course data repository
orders = pd.read_csv(f"{DATA_URL}/week08/orders.csv")
customers = pd.read_csv(f"{DATA_URL}/week08/customers.csv")

print("Orders:")
display(orders)
print("\nCustomers:")
display(customers)

# 1. Merge orders and customers


# 2. Total order amount per customer


# 3. Customer who spent the most


# 4. Average order amount by city


# 5. Customers with more than 2 orders

# %% [markdown]
# ---
# ## Exercise 4: Product Inventory Management (2 points)
#
# Analyze inventory data to help with stock management:
#
# 1. Calculate inventory value (Price * Quantity) for each product
# 2. Find products that are low stock (Quantity < 50)
# 3. Sort products by inventory value (highest to lowest)
# 4. Calculate total inventory value by supplier
# 5. Identify the top 3 products by inventory value

# %%
# Exercise 4: Your code here

# Load inventory data from course data repository
inventory = pd.read_csv(f"{DATA_URL}/week08/inventory.csv")

print("Inventory Data:")
display(inventory)

# 1. Calculate inventory value


# 2. Low stock products (< 50)


# 3. Sort by inventory value


# 4. Total value by supplier


# 5. Top 3 products by value

# %% [markdown]
# ---
# ## Exercise 5: Monthly Revenue Report (2 points)
#
# Create a comprehensive monthly revenue analysis:
#
# 1. Combine (concatenate) the three monthly DataFrames into one
# 2. Add a 'Month' column to identify each month
# 3. Calculate total revenue across all months by product
# 4. Find which month had the highest total revenue
# 5. Calculate the month-over-month growth rate for each product
#
# **Bonus:** Identify the product with the highest growth from January to March

# %%
# Exercise 5: Your code here

# Load monthly revenue data from course data repository
jan_revenue = pd.read_csv(f"{DATA_URL}/week08/jan_revenue.csv")
feb_revenue = pd.read_csv(f"{DATA_URL}/week08/feb_revenue.csv")
mar_revenue = pd.read_csv(f"{DATA_URL}/week08/mar_revenue.csv")

print("January Revenue:")
display(jan_revenue)
print("\nFebruary Revenue:")
display(feb_revenue)
print("\nMarch Revenue:")
display(mar_revenue)

# 1. Combine monthly DataFrames


# 2. Add Month column


# 3. Total revenue by product


# 4. Month with highest revenue


# 5. Month-over-month growth rate


# Bonus: Product with highest growth Jan to Mar

# %% [markdown]
# ---
# ## Submission Checklist
#
# Before submitting, verify:
#
# - [ ] All code cells run without errors
# - [ ] All exercises are completed
# - [ ] Student information is filled in
# - [ ] Code includes appropriate comments
#
# ---
# *ISM4641 Python for Business Analytics - Week 8 Practice Assignment*
